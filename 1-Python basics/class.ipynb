# %% [markdown]
# # the devils bride

# %%
import random
class Bank:
    amount=0
    def __init__(self,name,age,pin):
        self.name=name
        self.age=age
        self.pin=pin

        with open("bank.txt",'a') as f:
            f.write(f"{self.name,self.age,self.amount,self.pin}\n")


    def deposite(self,amount,name,pin):
        if(self.pin==pin and name==self.name):
            self.amount+=amount
        else:
            print("Wrong pin or name")
    
    def withdraw(self,amount,name,pin):
        if(self.name==name and self.pin==pin and amount<=self.withdraw):
            self.amount-=amount

    def show_details(self,name,pin):
        with open("bank.txt",'r') as f:
            x=f.read()
            print(x)

b=Bank("shani",12,4563)

b.deposite(100,"shani",4563)

b.show_details("shani",4563)

# %%
class parent:
    def __init__(self,name,age):
        self.name=name
        self.age=age

    def work(self):
        print("doing work for money")

class Child(parent):
    def __init__(self, name, age,color):
        super().__init__(name, age)
        self.color=color

    def play(self):
        print("I am playing")

    def study(self):
        print("Playing")

c=Child("shani",10,"white")
c.work()
# p=parent()
